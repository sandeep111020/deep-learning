# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep111020/deep-learning/blob/master/facedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/haarcascade_frontalface_default.xml')

# %%
img = cv2.imread('/content/drive/My Drive/sandeepa.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#FACES
faces = face_cascade.detectMultiScale(gray, 1.1, 4) #up#

# %%
for (x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x862 at 0x7F91D9C870B8>
