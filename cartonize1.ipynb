# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep111020/deep-learning/blob/master/cartonize1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot

# %%
img = cv2.imread('/content/drive/My Drive/sandeepa.jpg')#e')

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# %%
pyplot.imshow(img_gray)

# %%
img_gray = cv2.

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
pyplot.imshow(img_gray) #to

# %%
img_gray = cv2.medianBlur(img_gray, 7)

# %%
edges = cv2.Laplacian(img_gray, cv2.CV_8U , ksize = 5)
# t#cv_#c)
#%rerun
ret, mask = cv2.threshold(edges, 100, 255, cv2.THRESH_BINARY_INV)

# %%
img_gray = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
                        #sorted)

# %%
pyplot.imshow(img_gray)# GH)
